# %%
from astroptical.sextractor import finduncommonsrcs

# %%
catFiles=['../../05_SExtractor/Photometry/Catalogs/IC_F275WxF275W.cat',\
          '../../05_SExtractor/Photometry/Catalogs/IC_F475WxF475W.cat',\
           '../../05_SExtractor/Photometry/Catalogs/IC_F814WxF814W.cat']

# %%
finduncommonsrcs(catFiles,roiFile='../uncommon_srcs_roi/roi_all.reg',maxPixSep=30,writeRegions=True,circRegRadius=5,
                outDir='../uncommon_srcs_roi/')
# Out:
# ([     NUMBER     X_IMAGE     Y_IMAGE  FLUX_APER  FLUXERR_APER  MAG_APER  \
#   2       3.0   3771.6897   1193.9786   0.115894      0.015065   26.5088
#   3       4.0   3734.6851   1285.1119   0.291527      0.015450   25.5073
#   4       5.0   3796.0566   1363.4550   0.300514      0.014107   25.4743
#   5       6.0   4546.6875   1384.7590   1.645937      0.025635   23.6280
#   6       7.0   4566.7930   1388.8038   2.748687      0.047259   23.0712
#   7       8.0   4652.9707   1433.1329   1.150193      0.037162   24.0171
#   8       9.0   4641.3887   1431.4441   4.433944      0.037247   22.5520
#   9      10.0   4213.9180   1446.6724   0.149139      0.016125   26.2350
#   10     11.0   3351.9685   1537.4067   1.248395      0.025574   23.9281
#   11     12.0   4884.2134   1553.1399   2.913749      0.050630   23.0079
#   12     13.0   3632.1260   1733.6708   0.792832      0.019126   24.4210
#   13     14.0   4396.9189   1780.9446   0.255067      0.015274   25.6524
# ...

# %%
finduncommonsrcs(catFiles,roiFile='chip_gap_IC_UV.reg',maxPixSep=5,writeRegions=True,circRegRadius=5,
                outDir='./')
# Out:
# ([      NUMBER    X_IMAGE     Y_IMAGE  FLUX_APER  FLUXERR_APER  MAG_APER  \
#   0        1.0  3701.4841    970.0647   0.063223      0.019063   27.1668
#   1        2.0  3729.4829    996.2444   7.026852      0.040981   22.0521
#   2        3.0  3694.3032    980.8116  -0.411452      0.018759       NaN
#   3        4.0  3747.1799    980.9893   1.824359      0.026380   23.5162
#   4        5.0  3690.0347    987.9986   0.369629      0.020527   25.2496
#   ...      ...        ...         ...        ...           ...       ...
#   5152  5153.0  9391.3115  11199.3848   0.149686      0.019497   26.2310
#   5153  5154.0  9199.7207  11392.8740   1.428500      0.024929   23.7818
#   5154  5155.0  9711.6475  10873.0479   0.374404      0.020538   25.2356
#   5156  5157.0  9415.3887  11213.7637   0.143161      0.019455   26.2794
#   5157  5158.0  9376.1230  11055.1855   0.049432      0.019003   27.4340
#
#         MAGERR_APER
#   0          0.3275
#   1          0.0063
#   2             NaN
# ...
